# %% [markdown]
# <h2>Practice plots for ch. 9

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib notebook

# %%
# The data 
bor = pd.read_csv('C:\\Users\\Kitty\\Documents\\R\\HT2019\\Assignment 2\\borrelia.txt', sep = "\t")
bor.head()
# Out:
#    Number   Site Habitat Island  Borrelia_prevalence    PH  Temp
# 0       1  ASK01  Meadow    ASK                   27  7,36    21
# 1       2  ASK02  Meadow    ASK                   71   7,8    20
# 2       3  ASK03  Meadow    ASK                   66  7,99    21
# 3       4  ASK04  Meadow    ASK                   39   6,1    20
# 4       5  ASK05  Meadow    ASK                   32  7,29    17

# %%
bor['Borrelia_prevalence'].hist(bins = 30, xlabelsize = 12, ylabelsize = 12)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bor['Borrelia_prevalence'].hist(by = bor['Habitat'], xlabelsize = 12, ylabelsize = 12)
#plt.xlabel = ("Prevelance of Borrelia")
#plt.ylabel = ("Frequency")
#plt.ylim(0, 12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-36c853c7108f> in <module>
# ----> 1 bor['Borrelia_prevalence'].hist(by = bor['Habitat'], xlabelsize = 12, ylabelsize = 12)
#       2 plt.xlabel = ("Prevelance of Borrelia")
#       3 #plt.ylabel = ("Frequency")
#       4 #plt.ylim(0, 12)
#
# NameError: name 'bor' is not defined

# %%
sns.distplot(bor['Borrelia_prevalence'], kde = False)

# %% [markdown]
# <h2>NEW SESSION/NEW DATA

# %%
suicide = pd.read_csv('C:\\Users\\Kitty\\Documents\\R\\HT2019\\Final Project\\master PART 2 ttest.csv')
suicide.head()
# Out:
#    year     sex  suicides_no  suicides/100k pop  Unnamed: 4  Unnamed: 5  \
# 0  2016    male           12              19.37         NaN         NaN
# 1  2016    male           16               6.73         NaN         NaN
# 2  2016    male           16               4.56         NaN         NaN
# 3  2016    male            5               2.47         NaN         NaN
# 4  2016  female            2               1.95         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
suicide.drop('Unnamed: 4', inplace=True, axis=1)

# %%
suicide.drop('Unnamed: 5', inplace=True, axis=1)
suicide.head()
# Out:
#    year     sex  suicides_no  suicides/100k pop  Unnamed: 6
# 0  2016    male           12              19.37         NaN
# 1  2016    male           16               6.73         NaN
# 2  2016    male           16               4.56         NaN
# 3  2016    male            5               2.47         NaN
# 4  2016  female            2               1.95         NaN

# %%
suicide.drop('Unnamed: 6', inplace=True, axis=1)
suicide.head()
# Out:
#    year     sex  suicides_no  suicides/100k pop
# 0  2016    male           12              19.37
# 1  2016    male           16               6.73
# 2  2016    male           16               4.56
# 3  2016    male            5               2.47
# 4  2016  female            2               1.95

# %%
len(suicide)
# Out:
# 160

# %%
sns.distplot(suicide['suicides_no'], kde = False)

# %% [markdown]
# <h2> NEW ATTEMPT (3)<br> </h2>
#   <p>  https://dfrieds.com/data-visualizations/bar-plot-python-pandas.html

# %%
games = pd.read_csv('C:\\Users\\Kitty\\Documents\\R\\HT2019\\Final Project\\vgsales- first edit.csv')
games.head()
# Out:
#    Rank                       Name Platform  Year    Genre  Global_Sales
# 0   222                    FIFA 17      PS4  2016   Sports          4.77
# 1   352  Tom Clancy's The Division      PS4  2016  Shooter          3.61
# 2   772            Far Cry: Primal      PS4  2016   Action          2.13
# 3   847  Tom Clancy's The Division     XOne  2016  Shooter          2.01
# 4  1028                  Overwatch      PS4  2016  Shooter          1.73

# %%
games
# Out:
#       Rank                                               Name Platform  Year  \
# 0      222                                            FIFA 17      PS4  2016
# 1      352                          Tom Clancy's The Division      PS4  2016
# 2      772                                    Far Cry: Primal      PS4  2016
# 3      847                          Tom Clancy's The Division     XOne  2016
# 4     1028                                          Overwatch      PS4  2016
# ..     ...                                                ...      ...   ...
# 324  16477                  Total War Attila: Tyrants & Kings       PC  2016
# 325  16558              Codename: Panzers Complete Collection       PC  2016
# 326  15985  Super Battle For Money Sentouchuu: Kyuukyoku n...      3DS  2016
# 327  16001                     One Piece: Daikaizoku Coliseum      3DS  2016
# 328  16475                Azure Striker Gunvolt: Striker Pack      3DS  2016
#
#         Genre  Global_Sales
# ...

# %%
games['Genre'].value_counts()
# Out:
# Action          114
# Role-Playing     39
# Sports           34
# Adventure        34
# Shooter          31
# Racing           20
# Misc             18
# Fighting         11
# Strategy         10
# Platform          9
# Simulation        9
# Name: Genre, dtype: int64

# %%
sns.set(font_scale = 0.7)
games['Genre'].value_counts().plot(kind = 'bar', figsize = (7, 6), rot = 30, color = sns.color_palette("Greens_r"))
plt.xlabel("Count of appearence in data")
plt.ylabel("Video game genre")
plt.title("Count of video game genre from top 2016 sales")
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0.5, 1.0, 'Count of video game genre from top 2016 sales')

# %% [markdown]
# <br><h2> NEW ATTEMPT 4</h2><br>
#     <p>https://pythonbasics.org/seaborn-barplot/

# %%
bor = pd.read_csv('C:\\Users\\Kitty\\Downloads\\Assignment 2\\borrelia.txt', sep = "\t")
bor.head()
# Out:
#    Number   Site Habitat Island  Borrelia_prevalence    PH  Temp
# 0       1  ASK01  Meadow    ASK                   27  7,36    21
# 1       2  ASK02  Meadow    ASK                   71   7,8    20
# 2       3  ASK03  Meadow    ASK                   66  7,99    21
# 3       4  ASK04  Meadow    ASK                   39   6,1    20
# 4       5  ASK05  Meadow    ASK                   32  7,29    17

# %%
ax = sns.barplot(x = "Island", y = "Borrelia_prevalence", hue = "Habitat", data = bor,
           palette = "plasma")


#print(bor.groupby(['Island', 'Habitat']).mean()['Borrelia_prevalence'])
#print(bor.groupby(['Island', 'Habitat']).std()['Borrelia_prevalence'])

ax
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set(ylabel = "Prevalence of Borrelia", title = "Prevalence of Borrelia by Island")
# Out:
# [Text(49.25, 0.5, 'Prevalence of Borrelia'),
#  Text(0.5, 1.0, 'Prevalence of Borrelia by Island')]
